# %% [markdown]
# # Listas
#
# Vamos ver mais sobre listas mais adiante, mas por enquanto vamos nos preocupar em acessar itens específicos da lista. Esse tipo de conjunto pode ter vários nomes:
# - Listas
# - Arranjos
# - Arrays (arranjos em inglês)
# - Vetores
#
# Um detalhe importante sobre listas é que os seus índices sempre começam em 0. Por isso, uma lista com 10 elementos, por exemplo, terá do índice 0 até o índice 9 (0 a 9 são 10 elementos). Tente descobrir quantos elementos tem as seguintes listas:
#
# - Uma lista que vai de 0 a 10
# - Uma que vai de 0 a 99
# - E outra que vai de 0 a 14
#
# Fácil, não? E você saberia fazer o contrário? Diga quais são os índices para as listas abaixo:
#
# - Uma lista com 20 elementos
# - Uma com 18
# - E outra com 99
#
# Agora, vamos praticar acessar índices específicos das listas abaixo.

# %%
# a lista abaixo representa o numero de 
# filmes que você viu por mês durante o ano de 2020.
filmes_por_mes = [7, 10, 3, 15, 20, 18, 22, 32, 20, 22, 25, 30]

# %%
# armazene na variável abaixo o número 
# de filmes assistidos no primeiro mês do ano.
primeiro_mes = 
print(primeiro_mes)

# %%
# agora, o número de filmes 
# assistidos em dezembro.
dezembro = 
print(dezembro)

# %%
# qual o número de filmes assistidos 
# de junho a agosto? (complete)
junho_a_agosto = 
print(junho_a_agosto)

# %%
# qual a diferença entre o número de filmes 
# assistidos em maio e em setembro? (complete)
dif_maio_setembro = 
print(dif_maio_setembro)
